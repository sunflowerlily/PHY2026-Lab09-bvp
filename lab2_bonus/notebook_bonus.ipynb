# %% [markdown]
# # Bonus Lane-Emden 独立 Notebook
# 用于 Bonus 的 IVP 或 BVP 路线运行与结果记录。

# %%
from lab2_bonus.lane_emden import solve_lane_emden_ivp, estimate_xi1_and_omega3

# 路线 A: IVP
sol = solve_lane_emden_ivp(n=3, xi_max=12.0)
xi1, omega3 = estimate_xi1_and_omega3(sol)
print(f"xi1 = {xi1:.6f}")
print(f"omega3 = {omega3:.6f}")

# %%
# 路线 B: BVP（实现后可取消注释）
# from lab2_bonus.lane_emden import solve_lane_emden_bvp
# result = solve_lane_emden_bvp(n=3)
# print(result)
